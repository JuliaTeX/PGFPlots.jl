# %%
using PGFPlots
using Colors
f = (x,y)->x*exp(-x^2-y^2)
cm = colormap("RdBu")
Plots.Image(f, (-2,2), (-2,2), colormap = ColorMaps.RGBArrayMap([RGB(1.,0.,0.),RGB(0.,1.,0.), RGB(0.,0.,1.)], interpolation_levels=5050))
# Out:
# PGFPlots.Plots.Image("tmp_10000000000002.png", -2, 2, -2, 2, -0.42870694108441587, 0.42870694108441587, true, PGFPlots.ColorMaps.RGBArrayMap(ColorTypes.RGB{Float64}[RGB{Float64}(1.0,0.0,0.0), RGB{Float64}(0.0,1.0,0.0), RGB{Float64}(0.0,0.0,1.0)], 0x00000000000013ba), nothing)

# %%
save("test.pdf", Plots.Image(f, (-2,2), (-2,2), colormap = ColorMaps.RGBArrayMap([RGB(1.,0.,0.),RGB(0.,1.,0.), RGB(0.,0.,1.)], interpolation_levels=5050)))

# %%
cc =[RGB(0.5,0.9,0.1),RGB(0.5,0.9,0.9),RGB(0.5,0.3,0.9)]
typeof(cc)
# Out:
# Array{ColorTypes.RGB{Float64},1}

# %%
function InterpolatedRGBArrayMap(colors, levels = 256)
    n = length(colors)
    C = Vector{RGB{Float64}}(levels)    
    for (i, x) in enumerate(linspace(0, 1, levels))
        l = floor(UInt, 1 + x * (n-1))
        u = ceil(UInt, 1 + x * (n-1))
        α = 2*(1 + x * (n-1) - l)/(n-1)
        C[i] = (1-α)*colors[l] + (α)*colors[u]
    end
    RGBArrayMap(C)
end
InterpolatedRGBArrayMap([RGB(1.,0.,0.),RGB(0.,1.,0.), RGB(0.,0.,1.)])
# Out:
# UndefVarError: RGBArrayMap not defined
#
# Stacktrace:
#  [1] InterpolatedRGBArrayMap(::Array{ColorTypes.RGB{Float64},1}, ::Int64) at .\In[60]:10
#  [2] InterpolatedRGBArrayMap(::Array{ColorTypes.RGB{Float64},1}) at .\In[60]:2

# %%
InterpolatedRGBArrayMap([RGB(0.5,0.9,0.1),RGB(0.5,0.9,0.9),RGB(0.5,0.3,0.9)], 10)
# Out:
# 10-element Array{RGB{Float64},1}:
#  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)

# %%
cc[1]*0.2+cc[2]*0.8
# Out:
# RGB{Float64}(0.5,0.9000000000000001,0.7400000000000001)

# %%
include(Pkg.dir("PGFPlots", "src", "ndgrid.jl"))
using IndirectArrays
x = linspace(-2, 2, 400)
y = linspace(-2, 2, 400)
(X, Y) = meshgrid(x, y)
A = map(f, X, Y)
data = flipdim(A, 1)
C = [RGB(0.5,0.9,0.1),RGB(0.5,0.9,0.9),RGB(0.5,0.3,0.9)]
img = ImageMeta(IndirectArray([round(UInt8, v) for v in 1.+(length(C)-1).*(data)], C))
# Out:
# BoundsError: attempt to access 3-element Array{RGB{Float64},1} at index [UInt8[
# ...

# %%
using IndirectArrays, Colors

colors = distinguishable_colors(6)
index = rand(1:6, 32, 32)
A = IndirectArray(index, colors)
# Out:
# 32×32 IndirectArrays.IndirectArray{ColorTypes.RGB{FixedPointNumbers.Normed{UInt8,8}},2,Int64}:
#  RGB{N0f8}(0.0,0.0,0.0)      …  RGB{N0f8}(1.0,1.0,0.384)
#  RGB{N0f8}(0.0,0.502,0.161)     RGB{N0f8}(0.0,0.839,1.0)
#  RGB{N0f8}(0.0,0.0,0.0)         RGB{N0f8}(0.0,0.502,0.161)
#  RGB{N0f8}(0.0,0.502,0.161)     RGB{N0f8}(0.0,0.502,0.161)
#  RGB{N0f8}(0.0,0.0,0.0)         RGB{N0f8}(0.0,0.502,0.161)
#  RGB{N0f8}(0.0,0.502,0.161)  …  RGB{N0f8}(0.0,0.839,1.0)
#  RGB{N0f8}(0.0,0.839,1.0)       RGB{N0f8}(1.0,1.0,0.384)
#  RGB{N0f8}(1.0,0.624,1.0)       RGB{N0f8}(0.843,0.267,0.0)
#  RGB{N0f8}(0.843,0.267,0.0)     RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.0,0.0,0.0)         RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(1.0,0.624,1.0)    …  RGB{N0f8}(0.843,0.267,0.0)
#  RGB{N0f8}(0.0,0.839,1.0)       RGB{N0f8}(1.0,0.624,1.0)
#  RGB{N0f8}(0.0,0.0,0.0)         RGB{N0f8}(1.0,1.0,0.384)
#  ⋮                           ⋱
#  RGB{N0f8}(1.0,0.624,1.0)    …  RGB{N0f8}(0.0,0.502,0.161)
# ...

# %%
# Out:
# 32×32 Array{Int64,2}:
#  1  2  3  1  1  5  1  1  4  2  1  4  4  …  6  3  2  6  5  2  6  5  1  5  5  1
#  2  3  6  6  3  4  5  6  3  1  5  1  3     1  3  1  3  3  3  2  2  1  5  5  6
#  4  6  3  4  6  3  5  4  4  2  6  5  2     4  1  6  1  2  6  4  2  3  5  4  5
#  1  6  2  5  4  4  1  5  2  2  3  4  3     3  1  4  1  1  4  3  4  5  5  3  4
#  2  4  1  6  4  3  3  4  4  6  4  6  4     2  5  3  6  4  2  4  3  4  1  5  5
#  6  3  4  2  5  6  4  2  5  6  6  5  3  …  6  6  1  2  6  6  1  2  5  4  5  4
#  4  4  5  1  6  6  3  3  4  5  2  3  3     6  2  4  2  5  3  5  5  2  5  6  6
#  6  4  4  6  2  3  5  4  1  6  2  1  5     4  2  1  1  5  1  3  5  3  4  2  6
#  1  4  6  5  1  1  2  1  3  1  5  3  3     5  4  4  3  6  2  4  5  3  5  3  1
#  2  4  2  2  5  6  6  6  4  6  1  1  2     3  2  4  2  1  6  6  3  1  2  3  4
#  4  4  5  4  2  6  5  3  4  4  5  1  4  …  2  2  4  1  2  5  2  5  3  2  6  6
#  2  3  1  6  1  5  2  6  1  5  1  2  3     2  6  1  1  4  3  1  1  1  6  1  4
# ...
